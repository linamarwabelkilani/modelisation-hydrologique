# %% [markdown]
# <a href="https://colab.research.google.com/github/linamarwabelkilani/modelisation-hydrologique/blob/main/Copie_de_nanouchz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import dataset from github
import pandas as pd
data_url = "https://raw.githubusercontent.com/linamarwabelkilani/modelisation-hydrologique/main/Dataset.csv"
df = pd.read_csv(data_url, on_bad_lines='skip',sep=";")


df['Station']=df['Station'].astype(str)
df = df.astype({'Station':'string'})
df = df.astype({'Date':'string'})
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True,errors='coerce')
df = df.dropna()
print(df.dtypes)
df
# Out:
# Date             datetime64[ns]
# Station                  string
# Precipitation           float64
# dtype: object
#               Date               Station  Precipitation
# 0       1951-06-01  AIN BEYA OUED RHEZAL            0.0
# 1       1951-06-02  AIN BEYA OUED RHEZAL            0.0
# 2       1951-06-03  AIN BEYA OUED RHEZAL            0.0
# 3       1951-06-04  AIN BEYA OUED RHEZAL            0.0
# 4       1951-06-05  AIN BEYA OUED RHEZAL            0.0
# ...            ...                   ...            ...
# 2103688 2015-08-27         ZOUARINE GARE            3.0
# 2103689 2015-08-28         ZOUARINE GARE            7.0
# 2103690 2015-08-29         ZOUARINE GARE            0.0
# 2103691 2015-08-30         ZOUARINE GARE            0.0
# 2103692 2015-08-31         ZOUARINE GARE            0.0
#
# [2103693 rows x 3 columns]

# %%
import numpy as np
from scipy.interpolate import interp1d
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from pykrige import OrdinaryKriging

# Méthode de l'interpolation inverse probabiliste (IPW)
def inverse_probability_weighting(x, y, kind):
    # Indices des valeurs manquantes
    missing_indices = np.isnan(y)
    # Indices des valeurs connues
    known_indices = ~missing_indices
    # Valeurs connues de x et y
    x_known = x[known_indices]
    y_known = y[known_indices]
    # Application de l'interpolation inverse aux valeurs manquantes
    if kind == 'spline':
        spline_interpolator = interp1d(x_known, y_known, kind='cubic')
        y_predicted = spline_interpolator(x)
    else:
        ipw_interpolator = interp1d(x_known, y_known, kind=kind)
        y_predicted = ipw_interpolator(x)
    return y_predicted

# Liste des stations uniques
stations = df['Station'].unique()

# Types de kind à tester
kind_types = ['linear', 'nearest', 'zero', 'quadratic', 'cubic', 'spline']

# Parcours des stations
for station in stations:
    station_data = df[df['Station'] == station]
    x = np.arange(len(station_data))  # Utilisation de l'indice de la date comme variable indépendante
    y = station_data['Precipitation'].values  # Valeurs de précipitation

    best_kind = None
    best_mse = float('inf')
    best_mae = float('inf')
    best_r2 = -float('inf')

    # Test des différents types de kind
    for kind in kind_types:
        y_predicted = inverse_probability_weighting(x, y, kind)
        
        mse = mean_squared_error(y[~np.isnan(y)], y_predicted[~np.isnan(y)])
        mae = mean_absolute_error(y[~np.isnan(y)], y_predicted[~np.isnan(y)])
        r2 = r2_score(y[~np.isnan(y)], y_predicted[~np.isnan(y)])

        if mse < best_mse:
            best_kind = kind
            best_mse = mse
            best_mae = mae
            best_r2 = r2

    print(f"Station: {station}")
    print(f"Best Kind: {best_kind}")

    # Remplacer les valeurs manquantes par les valeurs prédites du type de kind le plus convenable
    y[np.isnan(y)] = y_predicted[np.isnan(y)]

    print("Metrics for the best kind:")
    print(f"MSE: {best_mse}")
    print(f"MAE: {best_mae}")
    print(f"R^2: {best_r2}")
# Out:
# Station: AIN BEYA OUED RHEZAL
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN DEBBA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN JEMMALA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN GUESIL 1
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN HAMRAYA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN KERMA 1
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN MERJA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN S'KOUM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN SALLEM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN TABIA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN TOUNGA SE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN ZARGA RETENUE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN ZARGA RUINE ROMA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN ZAKKAR
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN ZANA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN ZEBDA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AIN ZELIGUA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: AKOUAT GARE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BADROUNA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BALTA CTV
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BARRAGE KASSEB
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BARRAGE LAKMES
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BARRAGE SIDI SALEM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BATANE ECOLE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BATANE OMVVM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BESSOUAGUI  PF
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BORJ EL AMRI
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BORJ EL AIFA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BORDJ HAMDOUNA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BEN METIR 2 SM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BOU HEURTMA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: CHAOUAT
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: CHEMTOU RAOUDET SM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: CHEMTOU FERME
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: CHERFECH CRGR
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: CITE DU MELLEGUE SM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: DAOUESS FERME
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: JANTOURA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: DJEBEL KBOUCH PF
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: JERISSA DELEGATION
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: DEHMANI MUNICIPALITE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: EL ALIA SERS UCP
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: EL GUANTARA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: ELLES ECOLE SERS
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: FATH TESSA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: FELTA EP
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: FERNANA OUED RHEZALA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: FEIJA EL SM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: GAAFOUR DELEGATION
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: GDOUD UCP
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: GARDIMAOU DRE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: GHAR EL MELH NOUVEAU
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: GOUBELLAT
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: HAMMAM BAYADHA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: DJ BOU LAHNECH (E.PR
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: HIR MAZDOUR
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: EL HAOUD
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: JAMA DRE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: KALAA KHASBA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: KALAAT ANDALOUS
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: KALAAT ESSENAM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: KEF EN NESOUR
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: KEF.B.I.R.H
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: KEF HELIOPOLIS
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: KEF CMA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: KOUDIAT INRAT
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: KRIB FERME COSSEM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: KSAR BOU KLEIA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: KSOUR ECOLE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: KSAR TYR LES ALLOBRO
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: LABAR ECOLE SERS
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: LAAROUSSA AGRICOLE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: LORBEUS CTV
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: MAKTAR PF
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: MEJEZ EL BAB PF
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: MONTARNAUD 1
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: MUNCHAR ECOLE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: NEBEUR DELEGATION
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: NMAIRIA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: OUED EL LEBEN
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: OUED MLIZ INRAT
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: OUED MELLEGUE K 13
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: OUED RMIL
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: OUED TINE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: OUED ZARGA CTV
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: PARC CRDA BEJA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: PORTO FARINA GHAR ME
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: RAGHAY SUPERIEUR
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: REBAIEB
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SAKIET SIDI YOUSSEF
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SAKIT SIDI YOUSSEF P
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SENED EL HADDAD
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SERS AGRICOLE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SERS DELEGATION
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SIDI BOU ROUIS SM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SIDI BOUROUIS DELEGA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SIDI HAMADA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SIDI SAHBI ABIDA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SIDI THABET DOMAINE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SIDI THABET OMVVM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SILIANA BARRAGE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SILIANA II SM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SILIANA AGRICOLE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SILIANA LAOUJ
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SKHIRA BOU SALEM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SLOUGUIA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SMADAH UCP
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SODGA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SK EL ARBA(JENDOUBA)
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SK EL ARBA (JENDOUBA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: BOU SALEM DRE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SK EL KHEMIS B.S.CFP
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: SOUK ESSEBT
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: MORNAGUIA EX SI CYPR
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: TAJEROUINE AIN ZOUAG
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: TAJEROUINE FER D'ETA
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: TEBOURSOUK SM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: TESTOUR   SM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: TIBAR SM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: TOUIREF CTV
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: TOUKEBER
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: UTIQUE OMVVM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: ZAAFRANE UCP
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: ZEBIDA UCP ENNAJAT
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: ZOUEM SM
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0
# Station: ZOUARINE GARE
# Best Kind: linear
# Metrics for the best kind:
# MSE: 0.0
# MAE: 0.0
# R^2: 1.0

# %%
station_groups = df.groupby('Station')

# Créer une liste pour stocker les résultats
results = []

# Parcours des stations
for station_name, station_data in station_groups:
    # Compter le nombre de zéros dans la colonne 'Precipitation'
    zero_count = (station_data['Precipitation'] == 0).sum()
    # Calculer le pourcentage de zéros
    zero_percentage = zero_count / len(station_data) * 100
    # Ajouter les résultats à la liste
    results.append((station_name, zero_percentage))

# Trier les résultats par ordre croissant des pourcentages de zéros
sorted_results = sorted(results, key=lambda x: x[1])

# Afficher les stations avec les pourcentages de zéros
for station, percentage in sorted_results:
    print(f"Station: {station} - Pourcentage de zéros: {percentage}%")
# Out:
# Station: TIBAR SM - Pourcentage de zéros: 73.48592985318108%
# Station: BEN METIR 2 SM - Pourcentage de zéros: 74.07556756320818%
# Station: FEIJA EL SM - Pourcentage de zéros: 75.04981672365864%
# Station: KEF.B.I.R.H - Pourcentage de zéros: 75.70070876288659%
# Station: AIN DEBBA - Pourcentage de zéros: 75.76343955977505%
# Station: BARRAGE LAKMES - Pourcentage de zéros: 76.2273009735552%
# Station: BARRAGE KASSEB - Pourcentage de zéros: 76.29959213941416%
# Station: KEF CMA - Pourcentage de zéros: 76.34841909485431%
# Station: SMADAH UCP - Pourcentage de zéros: 76.61702127659574%
# Station: SK EL ARBA (JENDOUBA - Pourcentage de zéros: 77.09526019908195%
# Station: OUED MLIZ INRAT - Pourcentage de zéros: 77.11069418386491%
# Station: SLOUGUIA - Pourcentage de zéros: 77.2482651182552%
# Station: BOU HEURTMA - Pourcentage de zéros: 77.3529411764706%
# Station: GDOUD UCP - Pourcentage de zéros: 77.7001048584411%
# Station: BOU SALEM DRE - Pourcentage de zéros: 78.01422349633387%
# Station: KEF EN NESOUR - Pourcentage de zéros: 78.63686700896004%
# Station: CHERFECH CRGR - Pourcentage de zéros: 78.77835552254156%
# Station: AIN ZANA - Pourcentage de zéros: 79.16133477704498%
# Station: GARDIMAOU DRE - Pourcentage de zéros: 79.25113498449228%
# Station: JANTOURA - Pourcentage de zéros: 79.28233904311872%
# Station: AIN ZEBDA - Pourcentage de zéros: 79.44417357386641%
# Station: PORTO FARINA GHAR ME - Pourcentage de zéros: 79.44427845832088%
# Station: CITE DU MELLEGUE SM - Pourcentage de zéros: 79.54774648979908%
# Station: SK EL ARBA(JENDOUBA) - Pourcentage de zéros: 79.79160404769061%
# Station: OUED EL LEBEN - Pourcentage de zéros: 79.87124463519312%
# Station: SAKIET SIDI YOUSSEF  - Pourcentage de zéros: 79.9364248317128%
# Station: AIN BEYA OUED RHEZAL - Pourcentage de zéros: 79.95234484999459%
# Station: FERNANA OUED RHEZALA - Pourcentage de zéros: 79.99480159417779%
# Station: SILIANA BARRAGE - Pourcentage de zéros: 80.43024771838331%
# Station: KRIB FERME COSSEM - Pourcentage de zéros: 80.61052903893416%
# Station: TEBOURSOUK SM - Pourcentage de zéros: 80.72528135914794%
# Station: BARRAGE SIDI SALEM - Pourcentage de zéros: 80.76444103841364%
# Station: BESSOUAGUI  PF - Pourcentage de zéros: 80.84911423335369%
# Station: BALTA CTV - Pourcentage de zéros: 80.8558967835726%
# Station: DEHMANI MUNICIPALITE - Pourcentage de zéros: 80.992550934833%
# Station: AIN SALLEM - Pourcentage de zéros: 81.0677265159246%
# Station: SILIANA II SM - Pourcentage de zéros: 81.16072230707034%
# Station: PARC CRDA BEJA - Pourcentage de zéros: 81.21948884847325%
# Station: SIDI THABET OMVVM - Pourcentage de zéros: 81.29132231404958%
# Station: AIN HAMRAYA - Pourcentage de zéros: 81.32459840258458%
# Station: ZOUEM SM - Pourcentage de zéros: 81.56136761407055%
# Station: KOUDIAT INRAT - Pourcentage de zéros: 81.94705947502491%
# Station: TOUIREF CTV - Pourcentage de zéros: 82.00034399724802%
# Station: RAGHAY SUPERIEUR - Pourcentage de zéros: 82.00877258196417%
# Station: KALAAT ANDALOUS - Pourcentage de zéros: 82.09500609013398%
# Station: GHAR EL MELH NOUVEAU - Pourcentage de zéros: 82.18582887700535%
# Station: BORJ EL AMRI - Pourcentage de zéros: 82.22054760110525%
# Station: MUNCHAR ECOLE - Pourcentage de zéros: 82.30984701572936%
# Station: BADROUNA - Pourcentage de zéros: 82.32364659011014%
# Station: TESTOUR   SM - Pourcentage de zéros: 82.72964015151516%
# Station: MEJEZ EL BAB PF - Pourcentage de zéros: 82.73412504744861%
# Station: MORNAGUIA EX SI CYPR - Pourcentage de zéros: 82.73737617782074%
# Station: SKHIRA BOU SALEM - Pourcentage de zéros: 82.86882199925678%
# Station: SILIANA AGRICOLE - Pourcentage de zéros: 82.90065351639787%
# Station: CHAOUAT - Pourcentage de zéros: 82.94670846394985%
# Station: NEBEUR DELEGATION - Pourcentage de zéros: 82.98570116751935%
# Station: EL GUANTARA - Pourcentage de zéros: 83.01087578706354%
# Station: LAAROUSSA AGRICOLE - Pourcentage de zéros: 83.09991920280096%
# Station: SILIANA LAOUJ - Pourcentage de zéros: 83.22909927395587%
# Station: GOUBELLAT - Pourcentage de zéros: 83.33947387812248%
# Station: BORDJ HAMDOUNA - Pourcentage de zéros: 83.36469702672187%
# Station: MAKTAR PF - Pourcentage de zéros: 83.38159946535977%
# Station: BORJ EL AIFA - Pourcentage de zéros: 83.65530714130671%
# Station: BATANE OMVVM - Pourcentage de zéros: 83.71676662787576%
# Station: SIDI THABET DOMAINE  - Pourcentage de zéros: 83.7585481325618%
# Station: SERS AGRICOLE - Pourcentage de zéros: 83.76395741365879%
# Station: CHEMTOU FERME - Pourcentage de zéros: 83.80383039964573%
# Station: CHEMTOU RAOUDET SM - Pourcentage de zéros: 83.82252200031617%
# Station: KSAR BOU KLEIA - Pourcentage de zéros: 83.96817503729488%
# Station: ZAAFRANE UCP - Pourcentage de zéros: 83.99793654887799%
# Station: SIDI BOUROUIS DELEGA - Pourcentage de zéros: 84.01486988847584%
# Station: EL ALIA SERS UCP - Pourcentage de zéros: 84.4214967799245%
# Station: OUED ZARGA CTV - Pourcentage de zéros: 84.4610502610298%
# Station: LORBEUS CTV - Pourcentage de zéros: 84.60057747834456%
# Station: SAKIT SIDI YOUSSEF P - Pourcentage de zéros: 84.62505612932196%
# Station: SIDI BOU ROUIS SM - Pourcentage de zéros: 84.69380955554074%
# Station: AKOUAT GARE - Pourcentage de zéros: 84.83649156472376%
# Station: AIN MERJA - Pourcentage de zéros: 84.87209238079451%
# Station: SK EL KHEMIS B.S.CFP - Pourcentage de zéros: 84.91125948753067%
# Station: KSAR TYR LES ALLOBRO - Pourcentage de zéros: 84.94744361669558%
# Station: OUED MELLEGUE K 13 - Pourcentage de zéros: 85.04715088282504%
# Station: AIN TOUNGA SE - Pourcentage de zéros: 85.1544008366819%
# Station: MONTARNAUD 1 - Pourcentage de zéros: 85.17475955899602%
# Station: ZEBIDA UCP ENNAJAT - Pourcentage de zéros: 85.2020245346144%
# Station: AIN KERMA 1 - Pourcentage de zéros: 85.28930650131244%
# Station: SIDI HAMADA - Pourcentage de zéros: 85.3657294213529%
# Station: FATH TESSA - Pourcentage de zéros: 85.53757519274761%
# Station: DJEBEL KBOUCH PF - Pourcentage de zéros: 85.69129676813732%
# Station: DAOUESS FERME - Pourcentage de zéros: 85.76401612312202%
# Station: FELTA EP - Pourcentage de zéros: 85.82089552238806%
# Station: ZOUARINE GARE - Pourcentage de zéros: 85.84497131103171%
# Station: SERS DELEGATION - Pourcentage de zéros: 85.85199553282784%
# Station: KALAAT ESSENAM - Pourcentage de zéros: 85.89399200681387%
# Station: AIN ZELIGUA - Pourcentage de zéros: 85.95505617977528%
# Station: SOUK ESSEBT - Pourcentage de zéros: 86.02705120783116%
# Station: AIN JEMMALA - Pourcentage de zéros: 86.0715684994123%
# Station: HAMMAM BAYADHA - Pourcentage de zéros: 86.0898244252595%
# Station: KSOUR ECOLE - Pourcentage de zéros: 86.20967482032937%
# Station: GAAFOUR DELEGATION - Pourcentage de zéros: 86.29040977402963%
# Station: KALAA KHASBA - Pourcentage de zéros: 86.57455683003128%
# Station: UTIQUE OMVVM - Pourcentage de zéros: 86.77839851024208%
# Station: KEF HELIOPOLIS - Pourcentage de zéros: 86.83407325194229%
# Station: EL HAOUD - Pourcentage de zéros: 86.95240101095199%
# Station: JERISSA DELEGATION - Pourcentage de zéros: 87.04231371990312%
# Station: BATANE ECOLE - Pourcentage de zéros: 87.19473731639181%
# Station: LABAR ECOLE SERS - Pourcentage de zéros: 87.29450745507837%
# Station: AIN ZAKKAR - Pourcentage de zéros: 87.3570268807505%
# Station: AIN ZARGA RUINE ROMA - Pourcentage de zéros: 87.37410071942446%
# Station: JAMA DRE - Pourcentage de zéros: 87.70611057225995%
# Station: TOUKEBER - Pourcentage de zéros: 87.81418607711541%
# Station: AIN TABIA - Pourcentage de zéros: 88.08633269973635%
# Station: OUED TINE - Pourcentage de zéros: 88.09538038606347%
# Station: REBAIEB - Pourcentage de zéros: 88.12303829252983%
# Station: TAJEROUINE AIN ZOUAG - Pourcentage de zéros: 88.12935708752904%
# Station: SODGA - Pourcentage de zéros: 88.20399301860287%
# Station: TAJEROUINE FER D'ETA - Pourcentage de zéros: 88.46467439469673%
# Station: OUED RMIL - Pourcentage de zéros: 88.7590137241219%
# Station: AIN S'KOUM - Pourcentage de zéros: 88.78995580039715%
# Station: AIN ZARGA RETENUE - Pourcentage de zéros: 88.90041493775934%
# Station: SIDI SAHBI ABIDA - Pourcentage de zéros: 90.12789768185452%
# Station: ELLES ECOLE SERS - Pourcentage de zéros: 90.13986013986013%
# Station: NMAIRIA - Pourcentage de zéros: 91.10705437475552%
# Station: AIN GUESIL 1 - Pourcentage de zéros: 91.37677885701378%
# Station: DJ BOU LAHNECH (E.PR - Pourcentage de zéros: 92.39980685659101%
# Station: HIR MAZDOUR - Pourcentage de zéros: 93.1268561731014%
# Station: SENED EL HADDAD - Pourcentage de zéros: 93.21428571428572%

# %%
# Vérifier s'il y a des valeurs manquantes dans la colonne "Precipitation"
if df['Precipitation'].isnull().sum() == 0 and (df['Precipitation'] == '').sum() == 0:
    print("Aucune valeur manquante dans la colonne 'Precipitation'.")
else:
    print("Des valeurs manquantes sont présentes dans la colonne 'Precipitation'.")
# Out:
# Aucune valeur manquante dans la colonne 'Precipitation'.
